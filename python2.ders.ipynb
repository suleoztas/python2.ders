# %%
#geçerli değişken tanımlama
degisken_1=10
Degisken2=20
_degisken=30

# %%
#geçersiz değişken tanımlama
1degisken=40
degisken-4=50

# %%
#Değişken Tanımlama İşlemi
x=5
y="Merhaba Dünya"
print(x)
print(y)
# Out:
# 5
# Merhaba Dünya

# %%
#İnteger Tamsayı Tanımlaması
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
c="sule"
print(type(c))
# Out:
# <class 'str'>

# %%
#Float-Ondalık Sayı Tanımlaması
b=20.5
print(type(b))
# Out:
# <class 'float'>

# %%
#int'ten float'a çevrimin gerçekleştirilmesi
x=10
y=float(x)
print(y,type(y))
# Out:
# 10.0 <class 'float'>

# %%
z=20
t=float(z)
print(t,type(t))
# Out:
# 20.0 <class 'float'>

# %%
#String-Metinsel İçerik Tanımlama
c="Python Programlama"
print(c)
print(type(c))
# Out:
# Python Programlama
# <class 'str'>

# %%
#Boolean(True-False)-Doğru/Yanlış Tanımlaması
d=True
e=False
print(type(e))
print(d)
# Out:
# <class 'bool'>
# True

# %%
#List-Liste Tanımlaması
my_list=[1,2,3,4,5]
print(type(my_list))
print(my_list)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5]

# %%
#Tuple-Demet Tanımlaması
my_tuple=(1,2,3,4,5)
print(type(my_tuple))
print(my_tuple)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5)

# %%
#dictionary-Sözlük Örneği-Öğrencilerin Notlarını tutan bir sözlük
notlar={
    "Ali":85,
    "Veli":90,
    "Ayşe":78
}
notlar["Fatma"]=92
notlar["Ali"]=88
print(notlar)
# Out:
# {'Ali': 88, 'Veli': 90, 'Ayşe': 78, 'Fatma': 92}

# %%
print(notlar.keys())
print(notlar.values())
print(notlar.items())

#dict_keys(['Ali','Veli','Ayşe','Fatma'])
#dict_values([88,90,78,92])
#dict_items([('Ali',88),('Veli',90),('Ayşe',78),('Fatma',92)])
# Out:
# dict_keys(['Şule', 'İlayda', 'Gülnur', 'Ayşe'])
# dict_values([100, 80, 70, 60])
# dict_items([('Şule', 100), ('İlayda', 80), ('Gülnur', 70), ('Ayşe', 60)])

# %%
kodyazanlar={"Ahmet","Mehmet","Ayşe"}
kodyazmayanlar={"Ayşe","Fatma","Veli"}
ortak=kodyazanlar.intersection(kodyazmayanlar)
print("Kafasına göre takılan öğrencilerin listesi",ortak)
kod_yazmayan=kodyazmayanlar.difference(kodyazanlar)
print("Kod çalışması yapmayan öğrenci listesi",kod_yazmayan)
imza_listesi=(kodyazanlar.union(kodyazmayanlar))
print("Etkinlik katılımcıları:"), imza_listesi
# Out:
# Kafasına göre takılan öğrencilerin listesi {'Ayşe'}
# Kod çalışması yapmayan öğrenci listesi {'Veli', 'Fatma'}
# Etkinlik katılımcıları:
# (None, {'Ahmet', 'Ayşe', 'Fatma', 'Mehmet', 'Veli'})

# %%
giris=input("Bir sayı girin:")
try:
    num=float(giris)
    print(f"Girilen sayı: {num}, tipi: {type(num)}", abs(num))

except ValueError:
    print("Geçersiz veri girdiniz.")
# Out:
# Bir sayı girin:a
# Geçersiz veri girdiniz.
